# %% [markdown]
# ### Importing IPL Dataset

# %% [markdown]
# Here whenever using open(), we'll have to explicitly close the file pointer
#
# ipl_data = open()
#
# ipl_data.close()
#
# To avoid closing the file pointer externally, we can use 'with' keyword, so that it'll take care of closing the file pointer internally
#
# with open():

# %%
import pandas as pd

# %%
ipl_matches_df = pd.read_csv(r"Indian Premier League/matches.csv")

# %%
ipl_matches_df.count()
# Out:
# id                 756
# season             756
# city               749
# date               756
# team1              756
# team2              756
# toss_winner        756
# toss_decision      756
# result             756
# dl_applied         756
# winner             752
# win_by_runs        756
# win_by_wickets     756
# player_of_match    752
# venue              756
# umpire1            754
# umpire2            754
# umpire3            119
# dtype: int64

# %% [markdown]
# ### 1.Display top 10 rows of the dataset

# %%
ipl_matches_df.head(10)
# Out:
#    id  season       city        date                        team1
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field  \
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %% [markdown]
# ### 2. Check last 10 rows of the dataset

# %%
ipl_matches_df.tail(10)
# Out:
#         id  season           city      date                  team1
# 746  11342    2019         Mumbai  02/05/19         Mumbai Indians  \
# 747  11343    2019         Mohali  03/05/19        Kings XI Punjab
# 748  11344    2019          Delhi  04/05/19       Rajasthan Royals
# 749  11345    2019      Bengaluru  04/05/19    Sunrisers Hyderabad
# 750  11346    2019         Mohali  05/05/19    Chennai Super Kings
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                            team2                  toss_winner toss_decision
# 746          Sunrisers Hyderabad               Mumbai Indians           bat  \
# ...

# %% [markdown]
# ### 3. Find total number of rows and columns available in Dataset

# %%
ipl_matches_df.shape
# Out:
# (756, 18)

# %% [markdown]
# ### 4. Getting information about our dataset like Total number of rows, total number of columns, datatype of each column and memory required

# %%
ipl_matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# ### 5. Find out total number of NULL records in each column of DataFrame

# %%
ipl_matches_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# ### 6. Creating copy of original dataframe

# %%
ipl_matches_df_orig = ipl_matches_df.copy()

# %% [markdown]
# ### 7. Drop some columns from the DataFrame where NULL values are more

# %%
ipl_matches_df = ipl_matches_df.drop(['umpire1','umpire2','umpire3'], axis=1)

# %%
ipl_matches_df.shape
# Out:
# (756, 15)

# %% [markdown]
# ### 8. Find out player who received player_of_the_match (MOM) award most number of times

# %%
ipl_matches_df['player_of_match'].nunique()
# Out:
# 226

# %%
# value_counts() --> provides you the total number of occurances of each distinct value in a column
ipl_matches_df['player_of_match'].value_counts().head(1)
# Out:
# player_of_match
# CH Gayle    21
# Name: count, dtype: int64

# %% [markdown]
# ### 9. Get the unique count of teams participated in IPL history

# %%
ipl_matches_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
ipl_matches_df['team1'].nunique()
# Out:
# 15

# %% [markdown]
# ### 10. Get total number of records where match was a "Tie" between 2 teams

# %%
ipl_matches_df['result'].value_counts()
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %% [markdown]
# ### 11. Get the number of teams in which we've "Kings" keyword present in team name

# %%
len(ipl_matches_df[ipl_matches_df['team1'].str.contains('KINGS', case=False)])
# Out:
# 180

# %% [markdown]
# ### 12. Replace "CH Gayle" with "C Gayle" in winner column of dataframe

# %%
# Before replacing the value
ipl_matches_df['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %%
ipl_matches_df['player_of_match'] = ipl_matches_df['player_of_match'].replace('CH Gayle', 'C Gayle')

# %%
# After replacing the value
ipl_matches_df['player_of_match'].value_counts()
# Out:
# player_of_match
# C Gayle           21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %% [markdown]
# ### 13. Get total records where matches were played on "Wankhede Stadium"

# %%
# Filtering the records
# Approach 1 
ipl_matches_df[ipl_matches_df['venue'] == 'Wankhede Stadium']
# Out:
#         id  season    city        date                        team1
# 6        7    2017  Mumbai  2017-04-09        Kolkata Knight Riders  \
# 9       10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15      16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23      24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27      28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..     ...     ...     ...         ...                          ...
# 719  11315    2019  Mumbai    10/04/19              Kings XI Punjab
# 722  11318    2019  Mumbai    13/04/19               Mumbai Indians
# 726  11322    2019  Mumbai    15/04/19  Royal Challengers Bangalore
# 746  11342    2019  Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019  Mumbai    05/05/19        Kolkata Knight Riders
#
#                    team2       toss_winner toss_decision  result  dl_applied
# ...

# %%
# Approach 2
ipl_matches_df.query("venue == 'Wankhede Stadium'")
# Out:
#         id  season    city        date                        team1
# 6        7    2017  Mumbai  2017-04-09        Kolkata Knight Riders  \
# 9       10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15      16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23      24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27      28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..     ...     ...     ...         ...                          ...
# 719  11315    2019  Mumbai    10/04/19              Kings XI Punjab
# 722  11318    2019  Mumbai    13/04/19               Mumbai Indians
# 726  11322    2019  Mumbai    15/04/19  Royal Challengers Bangalore
# 746  11342    2019  Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019  Mumbai    05/05/19        Kolkata Knight Riders
#
#                    team2       toss_winner toss_decision  result  dl_applied
# ...

# %% [markdown]
# ### 14. Get venue wise total count of matches

# %%
ipl_matches_df.head(3)
# Out:
#    id  season       city        date                team1
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad  \
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field  \
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets
# 0  normal           0     Sunrisers Hyderabad           35               0  \
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# ...

# %%
# select venue, count(*) from ipl_matches
# group by venue

# ipl_matches_df.query('venue == "Saurashtra Cricket Association Stadium"')

ipl_matches_df.loc[ipl_matches_df['venue'] == 'Wankhede Stadium']
# Out:
#         id  season    city        date                        team1
# 6        7    2017  Mumbai  2017-04-09        Kolkata Knight Riders  \
# 9       10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15      16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23      24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27      28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..     ...     ...     ...         ...                          ...
# 719  11315    2019  Mumbai    10/04/19              Kings XI Punjab
# 722  11318    2019  Mumbai    13/04/19               Mumbai Indians
# 726  11322    2019  Mumbai    15/04/19  Royal Challengers Bangalore
# 746  11342    2019  Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019  Mumbai    05/05/19        Kolkata Knight Riders
#
#                    team2       toss_winner toss_decision  result  dl_applied
# ...

# %%
Saurashtra Cricket Association Stadium -> 10
Wankhede Stadium -> 73

# %%
ipl_matches_df['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
ipl_matches_df['win_by_runs'].unique()
# Out:
# array([ 35,   0,  15,  97,  17,  51,  27,   5,  21,  14,  26,  82,   3,
#         61,  48,  19,  12, 146,   7,   9,  10,  20,   1, 140,  33,   6,
#         66,  13,  45,  29,  18,  23,  41,  65,  25, 105,  75,  92,  11,
#         24,  38,   8,  78,  16,  53,   2,   4,  31,  55,  98,  34,  36,
#         39,  40,  67,  63,  37,  57,  22,  85,  32,  76, 111,  43,  58,
#         28,  74,  42,  59,  46,  47,  86,  44,  87, 130,  60,  77,  30,
#         50,  93,  72,  62, 138,  71, 144,  80,  64, 102, 118])

# %%
ipl_matches_df.groupby('venue')['id'].count()
# Out:
# venue
# ACA-VDCA Stadium                                         2
# Barabati Stadium                                         7
# Brabourne Stadium                                       11
# Buffalo Park                                             3
# De Beers Diamond Oval                                    3
# Dr DY Patil Sports Academy                              17
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Dubai International Cricket Stadium                      7
# Eden Gardens                                            77
# Feroz Shah Kotla                                        67
# Feroz Shah Kotla Ground                                  7
# Green Park                                               4
# Himachal Pradesh Cricket Association Stadium             9
# Holkar Cricket Stadium                                   9
# IS Bindra Stadium                                        7
# JSCA International Stadium Complex                       7
# ...

# %% [markdown]
# ### 15. Find out on how many venues IPL matches were played on

# %%
ipl_matches_df['venue'].nunique()
# Out:
# 41

# %% [markdown]
# ### 16. Check venue wise total winning percentage of team which has won the toss and match as well

# %%
ipl_matches_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue'],
#       dtype='object')

# %%
grouped = ipl_matches_df.groupby(['toss_winner', 'winner'])

# %%
winner_is_toss_winner = grouped.apply(lambda x : x[x['winner'] == x['toss_winner']])

# %%
type(winner_is_toss_winner)
# Out:
# pandas.core.frame.DataFrame

# %%
winner_is_toss_winner
# Out:
#                                                 id  season            city
# toss_winner         winner
# Chennai Super Kings Chennai Super Kings 60      61    2008      Chandigarh  \
#                                         73      74    2008       Bangalore
#                                         86      87    2008           Delhi
#                                         121    122    2009  Port Elizabeth
#                                         143    144    2009     East London
# ...                                            ...     ...             ...
# Sunrisers Hyderabad Sunrisers Hyderabad 642   7900    2018       Hyderabad
#                                         645   7903    2018         Kolkata
#                                         663   7921    2018          Jaipur
#                                         711  11152    2019           Delhi
#                                         733  11329    2019       Hyderabad
#
# ...

# %%
winner_is_toss_winner.groupby('venue').size().reset_index(name='count')
# Out:
#                                                 venue  count
# 0                                    ACA-VDCA Stadium      2
# 1                                    Barabati Stadium      5
# 2                                   Brabourne Stadium      7
# 3                                        Buffalo Park      2
# 4                               De Beers Diamond Oval      2
# 5                          Dr DY Patil Sports Academy      9
# 6   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      4
# 7                 Dubai International Cricket Stadium      3
# 8                                        Eden Gardens     43
# 9                                    Feroz Shah Kotla     33
# 10                            Feroz Shah Kotla Ground      5
# 11                                         Green Park      4
# 12       Himachal Pradesh Cricket Association Stadium      5
# 13                             Holkar Cricket Stadium      7
# ...

# %%
data = {'id' : [1,2,3,4,5],
     'name' : ['Mayur', 'Prajakta', 'Ram', 'Bhairav', 'Pooja'],
     'city' : ['Nasik', 'Pune', 'Nasik', 'Nasik', 'Pune']}

# %%
test_df = pd.DataFrame(data)

# %%
type(test_df)
# Out:
# pandas.core.frame.DataFrame

# %%
test_df
# Out:
#    id      name   city
# 0   1     Mayur  Nasik
# 1   2  Prajakta   Pune
# 2   3       Ram  Nasik
# 3   4   Bhairav  Nasik
# 4   5     Pooja   Pune

# %%
test_df['city'].value_counts()
# Out:
# city
# Nasik    3
# Pune     2
# Name: count, dtype: int64

# %%
test_df.groupby(['city']).size().reset_index(name='Number of people')
# Out:
#     city  Number of people
# 0  Nasik                 3
# 1   Pune                 2

# %%
test_df['pincode'] = ['10001','20001','10001','10002','20002']

# %%
test_df
# Out:
#    id      name   city pincode
# 0   1     Mayur  Nasik   10001
# 1   2  Prajakta   Pune   20001
# 2   3       Ram  Nasik   10001
# 3   4   Bhairav  Nasik   10002
# 4   5     Pooja   Pune   20002

# %%
test_df.groupby(['city','pincode']).size().reset_index(name='Number of people')
# Out:
#     city pincode  Number of people
# 0  Nasik   10001                 2
# 1  Nasik   10002                 1
# 2   Pune   20001                 1
# 3   Pune   20002                 1

# %%
# select city,pincode,count(*) from table_name group by city,pincode

# %%
test_df['Gender'] = ['M','F','M','M','F']

# %%
test_df
# Out:
#    id      name   city pincode Gender
# 0   1     Mayur  Nasik   10001      M
# 1   2  Prajakta   Pune   20001      F
# 2   3       Ram  Nasik   10001      M
# 3   4   Bhairav  Nasik   10002      M
# 4   5     Pooja   Pune   20002      F

# %%
test_df.drop('Gender', axis=1)
# Out:
#    id      name   city pincode
# 0   1     Mayur  Nasik   10001
# 1   2  Prajakta   Pune   20001
# 2   3       Ram  Nasik   10001
# 3   4   Bhairav  Nasik   10002
# 4   5     Pooja   Pune   20002
